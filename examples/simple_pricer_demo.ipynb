# %% [markdown]
# # Simple Pricer Demo
# Run locally or in Colab.

# %%
# !pip install numpy scipy --quiet

# %%
from pricer import bs_price, bond_pv, mini_swap_pv
bs_call = bs_price(100, 100, 0.03, 0.0, 0.2, 1.0, 'call')
bs_put = bs_price(100, 100, 0.03, 0.0, 0.2, 1.0, 'put')
bond = bond_pv(1000, 0.05, 0.04, 5, 2)
swap = mini_swap_pv(1_000_000, 0.04, 0.035, 5, 2, 'fixed')
bs_call, bs_put, bond, swap
